# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/camenduru/ios-emoji-xl-model-colab/blob/main/replicate_xl_lora_training.ipynb)

# %%
# !pip install replicate
import os
import replicate
from google.colab import output
from getpass import getpass
REPLICATE_API_TOKEN = getpass()
os.environ["REPLICATE_API_TOKEN"] = REPLICATE_API_TOKEN

# %%
import replicate
training = replicate.trainings.create(
    version="stability-ai/sdxl:d830ba5dabf8090ec0db6c10fc862c6eb1c929e1a194a5411852d25fd954ac82",
    input={
        "input_images": "https://huggingface.co/camenduru/ios-emoji-xl/resolve/main/dataset_72x72_images.zip",
    },
    destination="camenduru/sdxl-emoji"
)
